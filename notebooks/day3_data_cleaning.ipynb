# %% [markdown]
# # Day 3 - Data Cleaning
#
# - Standardize player names and team aliases
# - Handle missing values
# - Export cleaned dataset for SQL

# %%
import pandas as pd

# %%
deliveries = pd.read_csv("../data/processed/deliveries_2021_2023.csv")

deliveries.head()
# Out:
#    match_id  inning    batting_team                 bowling_team  over  ball  \
# 0   1254058       1  Mumbai Indians  Royal Challengers Bangalore     0     1
# 1   1254058       1  Mumbai Indians  Royal Challengers Bangalore     0     2
# 2   1254058       1  Mumbai Indians  Royal Challengers Bangalore     0     3
# 3   1254058       1  Mumbai Indians  Royal Challengers Bangalore     0     4
# 4   1254058       1  Mumbai Indians  Royal Challengers Bangalore     0     5
#
#       batter          bowler non_striker  batsman_runs  extra_runs  \
# 0  RG Sharma  Mohammed Siraj     CA Lynn             2           0
# 1  RG Sharma  Mohammed Siraj     CA Lynn             0           0
# 2  RG Sharma  Mohammed Siraj     CA Lynn             0           0
# 3  RG Sharma  Mohammed Siraj     CA Lynn             2           0
# 4  RG Sharma  Mohammed Siraj     CA Lynn             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
sorted(deliveries["batting_team"].unique())
# Out:
# ['Chennai Super Kings',
#  'Delhi Capitals',
#  'Gujarat Titans',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %%
sorted(deliveries["bowling_team"].unique())
# Out:
# ['Chennai Super Kings',
#  'Delhi Capitals',
#  'Gujarat Titans',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %%
sorted(deliveries["batter"].unique())
# Out:
# ['A Badoni',
#  'A Manohar',
#  'A Mishra',
#  'A Nortje',
#  'A Tomar',
#  'A Zampa',
#  'AB de Villiers',
#  'AD Russell',
#  'AF Milne',
#  'AJ Finch',
#  'AJ Hosein',
#  'AK Markram',
#  'AM Rahane',
#  'AR Patel',
#  'AS Joseph',
#  'AS Roy',
#  'AT Rayudu',
#  'AU Rashid',
#  'Abdul Basith',
#  'Abdul Samad',
#  'Abhishek Sharma',
#  'Abishek Porel',
#  'Akash Deep',
#  'Aman Hakim Khan',
#  'Anmolpreet Singh',
#  'Anuj Rawat',
#  'Arjun Tendulkar',
#  'Arshad Khan',
#  'Arshdeep Singh',
#  'Atharva Taide',
#  'Avesh Khan',
#  'B Indrajith',
#  'B Kumar',
#  'B Sai Sudharsan',
#  'BA Stokes',
#  'C Green',
#  'C Sakariya',
#  'CA Lynn',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Jordan',
#  'CR Woakes',
#  'CV Varun',
#  'D Brevis',
#  'D Padikkal',
#  'D Pretorius',
#  'D Wiese',
#  'DA Miller',
#  'DA Warner',
#  'DG Nalkande',
#  'DJ Bravo',
#  'DJ Hooda',
#  'DJ Malan',
#  'DJ Mitchell',
#  'DJ Willey',
#  'DL Chahar',
#  'DP Conway',
#  'DR Sams',
#  'DT Christian',
# ...

# %%
sorted(deliveries["bowler"].unique())
# Out:
# ['A Badoni',
#  'A Mishra',
#  'A Nortje',
#  'A Zampa',
#  'AD Russell',
#  'AF Milne',
#  'AJ Hosein',
#  'AJ Tye',
#  'AK Markram',
#  'AR Patel',
#  'AS Joseph',
#  'AS Roy',
#  'AU Rashid',
#  'Abdul Samad',
#  'Abhishek Sharma',
#  'Akash Deep',
#  'Akash Madhwal',
#  'Akash Singh',
#  'Aman Hakim Khan',
#  'Arjun Tendulkar',
#  'Arshad Khan',
#  'Arshdeep Singh',
#  'Avesh Khan',
#  'B Kumar',
#  'BA Stokes',
#  'Basil Thampi',
#  'C Green',
#  'C Sakariya',
#  'CH Morris',
#  'CJ Jordan',
#  'CR Woakes',
#  'CV Varun',
#  'D Brevis',
#  'D Jansen',
#  'D Pretorius',
#  'D Wiese',
#  'DG Nalkande',
#  'DJ Bravo',
#  'DJ Hooda',
#  'DJ Mitchell',
#  'DJ Willey',
#  'DL Chahar',
#  'DR Sams',
#  'DS Kulkarni',
#  'DT Christian',
#  'FA Allen',
#  'Fazalhaq Farooqi',
#  'GD Phillips',
#  'GHS Garton',
#  'GJ Maxwell',
#  'Gurnoor Brar',
#  'H Sharma',
#  'HH Pandya',
#  'HR Shokeen',
#  'HV Patel',
#  'Harbhajan Singh',
#  'Harpreet Brar',
#  'Harshit Rana',
#  'I Sharma',
# ...

# %%
deliveries["extras_type"].isnull().sum()
# Out:
# np.int64(47389)

# %%
deliveries["extras_type"] = deliveries["extras_type"].fillna("None")

# %%
deliveries["extras_type"].isnull().sum()
# Out:
# np.int64(0)

# %%
deliveries.to_csv(
    "../data/processed/deliveries_clean.csv",
    index=False
)
